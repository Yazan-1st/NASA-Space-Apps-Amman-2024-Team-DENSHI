# %% [markdown]
# https://climate.nasa.gov/vital-signs/global-temperature/?intent=111

# %%
# prompt: using pandas  open the temperatures_index.csv file

import pandas as pd

# Assuming the file is in the current working directory
df = pd.read_csv('/content/temperatures_index.csv')

# You can print the DataFrame to see its contents
df
# Out:
#      Year  No_Smoothing  Lowess(5)
# 0    1880         -0.17      -0.09
# 1    1881         -0.09      -0.13
# 2    1882         -0.11      -0.17
# 3    1883         -0.17      -0.20
# 4    1884         -0.28      -0.24
# ..    ...           ...        ...
# 139  2019          0.98       0.93
# 140  2020          1.01       0.95
# 141  2021          0.85       0.97
# 142  2022          0.89       0.99
# 143  2023          1.17       1.01
#
# [144 rows x 3 columns]

# %%
# @title Lowess(5)

from matplotlib import pyplot as plt
df['Lowess(5)'].plot(kind='line', figsize=(8, 4), title='Lowess(5)')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
df = df[df['Year'] >= 1993]
df
# Out:
#      Year  No_Smoothing  Lowess(5)
# 113  1993          0.23       0.33
# 114  1994          0.31       0.34
# 115  1995          0.44       0.36
# 116  1996          0.33       0.40
# 117  1997          0.46       0.42
# 118  1998          0.61       0.44
# 119  1999          0.38       0.47
# 120  2000          0.39       0.50
# 121  2001          0.53       0.52
# 122  2002          0.63       0.55
# 123  2003          0.62       0.58
# 124  2004          0.53       0.61
# 125  2005          0.68       0.62
# 126  2006          0.64       0.62
# 127  2007          0.66       0.63
# 128  2008          0.54       0.64
# 129  2009          0.65       0.64
# 130  2010          0.72       0.64
# 131  2011          0.61       0.66
# 132  2012          0.64       0.69
# 133  2013          0.67       0.74
# 134  2014          0.75       0.78
# 135  2015          0.90       0.83
# 136  2016          1.01       0.87
# 137  2017          0.92       0.91
# 138  2018          0.85       0.93
# ...

# %%
# @title Lowess(5)

from matplotlib import pyplot as plt
grouped_df = df.groupby('Year')['Lowess(5)'].mean()
grouped_df
# Out:
# Year
# 1993    0.33
# 1994    0.34
# 1995    0.36
# 1996    0.40
# 1997    0.42
# 1998    0.44
# 1999    0.47
# 2000    0.50
# 2001    0.52
# 2002    0.55
# 2003    0.58
# 2004    0.61
# 2005    0.62
# 2006    0.62
# 2007    0.63
# 2008    0.64
# 2009    0.64
# 2010    0.64
# 2011    0.66
# 2012    0.69
# 2013    0.74
# 2014    0.78
# 2015    0.83
# 2016    0.87
# 2017    0.91
# 2018    0.93
# 2019    0.93
# 2020    0.95
# 2021    0.97
# 2022    0.99
# 2023    1.01
# Name: Lowess(5), dtype: float64

# %%
grouped_df.plot(kind='line', figsize=(8, 4), title='Lowess(5)', marker='o')
# Out:
# <Axes: title={'center': 'Lowess(5)'}, xlabel='Year'>

# %%
grouped_df.to_csv('temperatures.csv')
