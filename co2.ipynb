# %% [markdown]
# ### Refrence

# %% [markdown]
#  https://climate.nasa.gov/vital-signs/carbon-dioxide/?intent=121

# %% [markdown]
# ### import

# %%
import pandas as pd
import re
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("co2_mm_mlo.csv")
df
# Out:
#      Year  Month  Decimal Date  Monthly Average  Deseasonalized  Days  StDev  \
# 0    1958      3     1958.2027           315.71          314.44    -1  -9.99
# 1    1958      4     1958.2877           317.45          315.16    -1  -9.99
# 2    1958      5     1958.3699           317.51          314.69    -1  -9.99
# 3    1958      6     1958.4548           317.27          315.15    -1  -9.99
# 4    1958      7     1958.5370           315.87          315.20    -1  -9.99
# ..    ...    ...           ...              ...             ...   ...    ...
# 793  2024      4     2024.2917           426.51          423.99    22   0.99
# 794  2024      5     2024.3750           426.90          423.62    29   0.76
# 795  2024      6     2024.4583           426.91          424.45    20   0.65
# 796  2024      7     2024.5417           425.55          425.07    24   0.69
# 797  2024      8     2024.6250           422.99          424.85    22   1.07
#
#       Unc
# 0   -0.99
# 1   -0.99
# 2   -0.99
# 3   -0.99
# 4   -0.99
# ..    ...
# 793  0.40
# 794  0.27
# 795  0.28
# 796  0.27
# 797  0.44
#
# [798 rows x 8 columns]

# %%
df1=pd.DataFrame(df.groupby('Year')['Monthly Average'].mean())

# %%
df1.to_csv("output.csv")
